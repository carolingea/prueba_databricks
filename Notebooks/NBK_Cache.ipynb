# %%
# %sql
-- CACHÉ
-- CACHE TABLE workspace.default.products_2000000

-- SELECT * FROM workspace.default.products_2000000 WHERE Price > 200
SELECT current_user()

# %%
df = spark.table("workspace.default.products_2000000")
display(df.limit(10))
