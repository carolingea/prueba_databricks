-- %%
-- OPTIMIZAR
OPTIMIZE workspace.default.products_200000_cluster;

CREATE CATALOG IF NOT EXISTS PRODUCCION;
CREATE SCHEMA IF NOT EXISTS prueba.carolingea;

DROP CATALOG produccion;

select * from desarrollo.default.sample_trips_prueba;

SELECT * FROM carolingea.sample_trips_prueba;
