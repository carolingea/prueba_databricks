# %%
#/Volumes/workspace/default/volumen_carol/prueba1.csv

#Etapa bronze: aca se lee el archivo crudo montado en Catalog / Schema / Volumen
print ('Etapa bronze')
#leemos el archivo, format le indica el formato, header que tiene la fila de cabecera, inferSchema para que infiera el tipo de dato y load para indicar el path
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("delimiter", ";") \
    .load("/Volumes/workspace/default/volumen_carol/prueba1.csv")
#muestra lo que se leyo en el data frame
display(df)

# %%
df_clean = df.withColumn("Nombre", upper(col("Nombre"))) \
    .withColumn("Apellido", upper(col("Apellido"))) \
    .withColumn("Edad", upper(col("Edad"))) \
    .withColumn("Ciudad", upper(col("Ciudad"))) \
    .withColumn("Departamento", upper(col("Departamento"))) \
    .dropna(how="any", subset=["Nombre", "Apellido", "Edad"])
display(df_clean)

#df_clean.write.mode("overwrite").saveAsTable("default.datos")

# %%
df_clean.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("workspace.default.personas")

# %%
# %sql
select * from workspace.default.personas
